# %%
import numpy as np

# %% [markdown]
# # ROOT

# %% [markdown]
# We observe the change in the altitude of an airplane, which we describe with the function:$$h(t)= h_0 + A\,\sin{\Big(\frac{2\,\pi}{t_k}\, t\Big)}^4 $$and the observation time is defined on the interval $t\in[0,\, t_k]$ with $n$ equidistantly distributed points.

# %% [markdown]
# <img width='600px' src='NIC.jpeg'>

# %%
h_0 = 5100 # m
A = 180 # m
n = 2000 # /
t_k = 134 # s

# %% [markdown]
# ### Question 1
#
#  A polynomial has a root at a local extremum. Can we reliably detect it with the Newton-Raphson method? (1:Yes, 2:No)

# %%
answer1 = # #?

# %% [markdown]
# ### Question 2
#
#  Determine the numerical array of values $h(t)$.
#
# Units: m

# %%
answer2 = # #?

# %% [markdown]
# ### Question 3
#
#  Determine the numerical array of values of the first derivative $\dot{h}(t)$. For the differentiation, use the `sympy` module.
#
# Units: m/s

# %%
answer3 = # #?

# %% [markdown]
# ### Question 4
#
#  Using the Newton-Raphson method, determine the numerical array of values of the times at which the airplane crosses the altitude $h_0+\frac{A}{10}$.
#
# Units: s

# %%
answer4 = # #?

# %% [markdown]
# ### Question 5
#
#  Using the secant method, determine the numerical array of times at which the velocity is maximal.
#
# Units: s

# %%
answer5 = # #?
