# %%
import numpy as np

# %% [markdown]
# # INP

# %% [markdown]
# The figure shows the measured temperature of water. A table of temperature $T$ as a function of time $t$ is given. An interpolation curve is fitted through the measured points.

# %% [markdown]
# <img width='600px' src='INP.jpeg'>

# %%
t = 65 # s
t_0 = 50.8 # s
t_1 = 61.9 # s
t_2 = 70.8 # s
t_3 = 80.8 # s
t_4 = 90.9 # s
t_5 = 99.2 # s
T_0 = -28.2 # °C
T_1 = -18.8 # °C
T_2 = -9.7 # °C
T_3 = 9.4 # °C
T_4 = 18.9 # °C
T_5 = 28.7 # °C

# %% [markdown]
# ### Question 1
#
#  Are high-degree polynomials generally well-conditioned? (1: Yes, 2: No)

# %%
answer1 = # #?

# %% [markdown]
# ### Question 2
#
#  Can we fit a 3rd-degree polynomial through any 5 arbitrary points? (1: Yes, 2: No)

# %%
answer2 = # #?

# %% [markdown]
# ### Question 3
#
#  Compute the interpolation polynomial. Enter the numerical array of polynomial coefficients (start with the coefficient of the highest-power term).

# %%
answer3 = # #?

# %% [markdown]
# ### Question 4
#
#  Enter the interpolated water temperature at time $t$.
#
# Units: °C

# %%
answer4 = # #?

# %% [markdown]
# ### Question 5
#
#  Enter the time at which the temperature crosses 0°C.
#
# Units: s

# %%
answer5 = # #?
