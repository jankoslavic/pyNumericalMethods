# %%
import numpy as np

# %% [markdown]
# # ODV-001

# %% [markdown]
# The figure shows a cantilever beam with a support and an increasing load. The force $F$, the beam length $l$, and the maximum value of the distributed load $w$ are given. Assume that the internal moment in the beam is defined by the expression $M(x)=F\,x-w\,x^3/(6\,l)$.

# %% [markdown]
# <img width='700px' src='ODV.jpeg'>

# %%
F = 1500 # N
l = 12 # m
h = 0.4 # m
n = 149 #
w = 1822.7 # N/m

# %% [markdown]
# ### Question 1
#
#  Differentiation is a numerically worse-conditioned method than integration! (1: Yes, 2: No)

# %%
answer1 = # #?

# %% [markdown]
# ### Question 2
#
#  The central difference scheme takes into account only points ahead of the current point of computation! (1: Yes, 2: No)

# %%
answer2 = # #?

# %% [markdown]
# ### Question 3
#
#  Determine the numerical derivative $M'(x)$ at the point $x=h$: use the backward difference scheme (step $h$, error order $\mathcal{O}(h^{1})$).
#
# Units: N

# %%
answer3 = # #?

# %% [markdown]
# ### Question 4
#
#  Determine the numerical derivative $M'(x)$ at the point $x=h$: use the central difference scheme (step $h$, error order $\mathcal{O}(h^{2})$).
#
# Units: N

# %%
answer4 = # #?

# %% [markdown]
# ### Question 5
#
#  Divide the entire beam into $n$ equidistant segments of width $b$. Determine $b$.
#
# Units: m

# %%
answer5 = # #?

# %% [markdown]
# ### Question 6
#
#  Using the central difference scheme with error order $\mathcal{O}(h^{2})$, determine the numerical derivative $M'(x)$ at the interior, previously determined, equidistant points.
#
# Units: N

# %%
answer6 = # #?
