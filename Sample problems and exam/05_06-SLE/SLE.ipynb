# %%
import numpy as np

# %% [markdown]
# # SLE

# %% [markdown]
# A cantilever beam with a support is shown. The forces $G_1$, $G_2$, $G_3$, the angles $\alpha$ and $\beta$, the beam length $l$, the points of application of the forces $a$ and $b$, and the distributed load $q$ are given.

# %% [markdown]
# <img width=600 src='SLE.jpeg'>

# %%
G_1 = 600 # N
G_2 = 800 # N
G_3 = 500 # N
alpha = 0.9 # rad
beta = 0.4 # rad
l = 9 # m
a = 7.5 # m
b = 4.5 # m
q = 90 # N/m

# %% [markdown]
# ### Question 1
#
#  If the determinant of the coefficient matrix equals zero, the system of linear equations has a unique solution! (1: Yes, 2: No)

# %%
answer1 = # #?

# %% [markdown]
# ### Question 2
#
#  Set up the system of linear equations. Determine the vector of unknowns (as a string, separated by commas, in alphabetical order).

# %%
answer2 = # #?

# %% [markdown]
# ### Question 3
#
#  Determine the coefficient matrix. For the solution to be unique, the diagonal coefficients should be $[1,1,1]$.

# %%
answer3 = # #?

# %% [markdown]
# ### Question 4
#
#  Determine the vector of constants!
#
# Units: N, N, Nm

# %%
answer4 = # #?

# %% [markdown]
# ### Question 5
#
#  Determine the solution of the system of linear equations.
#
# Units: N, N, Nm

# %%
answer5 = # #?

# %% [markdown]
# ### Question 6
#
#  Determine the Euclidean norm of the coefficient matrix.

# %%
answer6 = # #?
