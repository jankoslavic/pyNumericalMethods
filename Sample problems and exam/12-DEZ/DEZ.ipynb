# %%
import numpy as np

# %% [markdown]
# # ODE

# %% [markdown]
# In a simple circuit with a resistor of resistance $R$ and a capacitor of capacitance $C$, we close the switch, so the voltage $u$ starts to drop with time $t$. The differential equation that describes the circuit is $u'=u/(R\,C)$.

# %% [markdown]
# <img width='600px' src='DEZ.jpeg'>

# %%
C = 9.3e-06 # F
R = 200000 # Ohm
u_0 = 2.2 # V
t_0 = 2 # s
n = 97 #

# %% [markdown]
# ### Question 1
#
#  In an initial value problem for solving differential equations, we are given the values of the dependent variable at the initial and final points! (1: Yes, 2: No)

# %%
answer1 = # #?

# %% [markdown]
# ### Question 2
#
#  A second-order differential equation is solved as a system of first-order differential equations!  (1: Yes, 2: No)

# %%
answer2 = # #?

# %% [markdown]
# ### Question 3
#
#  First apply the initial condition $u(0)=u_0$ and solve the differential equation symbolically. Then determine $u(t_0)$.
#
# Units: V

# %%
answer3 = # #?

# %% [markdown]
# ### Question 4
#
#  Divide the time interval $[0, t_0]$ into $n$ equal segments $\Delta t$. Determine the width of a segment $\Delta t$.
#
# Units: s

# %%
answer4 = # #?

# %% [markdown]
# ### Question 5
#
#  Using Euler's method, determine the voltage over the interval $[0, t_0]$ s (use the step $\Delta t$ and the initial condition $u(0)=u_0$).
#
# Units: V

# %%
answer5 = # #?
