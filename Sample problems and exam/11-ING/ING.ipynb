# %%
import numpy as np

# %% [markdown]
# # ING

# %% [markdown]
# The figure shows the trajectory of a ball moving in a plane. The acceleration in the $x$ coordinate is given by the expression $p(t) = a\,t^2+b\,t+c$.

# %% [markdown]
# <img width='600px' src='ING.jpeg'>

# %%
a = 0.04 # m/s$^4$
b = 0.19 # m/s$^3$
c = 1.65 # m/s$^2$
n = 80 #
t_2 = 23.4 # s

# %% [markdown]
# ### Question 1
#
#  The trapezoidal rule can also be used to compute the numerical integral at the initial point of a given sequence. (1: Yes, 2: No)

# %%
answer1 = # #?

# %% [markdown]
# ### Question 2
#
#  Determine the numerical integral $\int_{0}^{t_2} p(x)\,dx$ using the composite trapezoidal method with step $t_2$.
#
# Units: m/s

# %%
answer2 = # #?

# %% [markdown]
# ### Question 3
#
#  Determine the numerical integral $\int_{0}^{t_2} p(t)\,dx$ using the composite trapezoidal method with step $t_2/2$.
#
# Units: m/s

# %%
answer3 = # #?

# %% [markdown]
# ### Question 4
#
#  Based on the integrals computed above with step $t_2$ and $t_2/2$, determine an improved estimate of the integral.
#
# Units: m/s

# %%
answer4 = # #?

# %% [markdown]
# ### Question 5
#
#  Divide the observed time interval $[0,t_2]$ into $n$ equidistant segments with step $h$. Determine the step $h$.
#
# Units: s

# %%
answer5 = # #?

# %% [markdown]
# ### Question 6
#
#  Using the cumulative trapezoidal method (`scipy.integrate.cumtrapz`), compute the value of the integral at all discrete points using step $h$. (That is: $\int_{0}^{t_i} p(x)\,dx$), where $t_i$ is a discrete point.
#
# Units: m/s

# %%
answer6 = # #?
