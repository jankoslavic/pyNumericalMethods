# %%
import numpy as np

# %% [markdown]
# # Exam NM / PiNM, problem 1

# %% [markdown]
# ## Problem 1: Root finding

# %% [markdown]
# We are given a crank mechanism with cranks of lengths $r$ and $l$ and the given piston velocity: $$x'(\alpha)= -r\,\sin{(\alpha)}-\frac{r^2\,\sin{\alpha}\,\cos{\alpha}}{\sqrt{l^2-(r\,\sin{\alpha})^2}}$$Here the angle alpha is defined on the interval $\alpha\in[0, 2\pi]$ with $n$ points.

# %% [markdown]
# <img width=500 src='slika_NIC.jpg'>

# %%
A = -1 # m/s
l = 1.7999999999999998 # m
n = 5000 # /
r = 1.3 # m

# %% [markdown]
# ### Question 1
#
#  The Newton-Raphson method is one of the iterative root-finding methods. (1:Yes, 2:No)

# %%
answer1 = #?

# %% [markdown]
# ### Question 2
#
#  Determine the values of $x'(\alpha)$.
#
# Units:  m/s

# %%
answer2 = #?

# %% [markdown]
# ### Question 3
#
#  Determine the values of the acceleration $x''(\alpha)$. (Hint: you can use the `sympy` module to help with differentiation.)
#
# Units:  m/s$^2$

# %%
answer3 = #?

# %% [markdown]
# ### Question 4
#
#  Using the Newton-Raphson method, determine the list of angles $\alpha$ on the interval $\alpha\in[0,\,2\pi]$ where the velocity $\dot{x}(\alpha)$ is equal to zero. Use the function `scipy.optimize.newton`.
#
# Units:  rad

# %%
answer4 = #?

# %% [markdown]
# ### Question 5
#
#  Using the secant method, determine the position $\alpha$ where the piston has the lowest velocity.
#
# Units:  rad

# %%
answer5 = #?
