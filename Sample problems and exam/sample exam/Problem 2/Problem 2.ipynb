# %%
import numpy as np

# %% [markdown]
# # Exam NM / PiNM, problem 2

# %% [markdown]
# ## Problem 2: Numerical solution of differential equations

# %% [markdown]
# You enjoy running, but you often have problems with your joints due to the transmissibility of the vibration isolation in your running shoes. You want to reduce the transmissibility, so you measured the mass $m$, the stiffness $k$, and the damping factor $d$ of your shoes. Model the shod runner with the differential equation $m\,\ddot{x}(t) + d\,\dot{x}(t) + k\,x(t)=F(t)$, where the force $F(t)$ is defined as $F(t)=C\,t^2+8\,D\,t\,\arctan{(\omega\,t)}$ and the time $t$ is defined by $n$ points over the interval $t\in[t_0, t_1]$.

# %% [markdown]
# <img width=500 src='slika_DEZ.jpg'>

# %%
omega = 3.5 # rad/s
C = 300 # N/s^2
D = 1 # N/s
d = 117 # Nm/s
k = 150000 # N/m
m = 0.25 # kg
n = 1900 #
t_0 = 4.0E-4 # s
t_1 = 0.01 # s

# %% [markdown]
# ### Question 1
#
# The size of the time step significantly affects the final solution of an ordinary differential equation (initial value problem) (1: Yes, 2: No).

# %%
answer1 = #?

# %% [markdown]
# ### Question 2
#
#  Determine the numerical array of the force $F(t)$.
#
# Units:  N

# %%
answer2 = #?

# %% [markdown]
# ### Question 3
#
#  Using the function `scipy.integrate.odeint`, solve the differential equation and determine the numerical array of displacements $x(t)$.  For the initial conditions use $x(t_0) = 0$ and $\dot{x}(t_0) = 0$.
#
# Units:  m

# %%
answer3 = #?

# %% [markdown]
# ### Question 4
#
#  Determine the numerical array of velocities $\dot{x}(t)$.
#
# Units:  m/s

# %%
answer4 = #?

# %% [markdown]
# ### Question 5
#
#  Also determine the numerical array of accelerations $\ddot{x}(t)$.
#
# Units:  m/s$^2$

# %%
answer5 = #?
