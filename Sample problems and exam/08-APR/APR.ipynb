# %%
import numpy as np

# %% [markdown]
# # APR

# %% [markdown]
# The figure shows the measured water temperature. A table of the temperature $T$ as a function of time $t$ is given. We want to determine an approximating polynomial of degree $s$ through the measured points.

# %% [markdown]
# <img width='600px' src='APR.jpeg'>

# %%
s = 3 #
t = 62 # s
t_1 = 51.9 # s
t_2 = 61.2 # s
t_3 = 71.2 # s
t_4 = 80.4 # s
t_5 = 91.5 # s
t_6 = 98.2 # s
T_1 = -29.1 # °C
T_2 = -19.1 # °C
T_3 = -8.3 # °C
T_4 = 8.4 # °C
T_5 = 18.9 # °C
T_6 = 29.3 # °C

# %% [markdown]
# ### Question 1
#
#  We determine the approximating curve based on the maximum of the squared residuals! (1: Yes, 2: No)

# %%
answer1 = # #?

# %% [markdown]
# ### Question 2
#
#  In approximation we typically use high-degree polynomials! (1: Yes, 2: No)

# %%
answer2 = # #?

# %% [markdown]
# ### Question 3
#
#  Determine the approximating polynomial of degree $s$. Enter the numerical array of polynomial coefficients (start with the coefficient of the highest-power term).

# %%
answer3 = # #?

# %% [markdown]
# ### Question 4
#
#  Determine the approximated water temperature at time $t$.
#
# Units: °C

# %%
answer4 = # #?

# %% [markdown]
# ### Question 5
#
#  Determine the time at which the temperature crosses 0°C.
#
# Units: s

# %%
answer5 = # #?
