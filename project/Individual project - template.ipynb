# %% [markdown]
# Author: **First and last name, enrollment number**
#
# Date: January 1, 2024
#
# *I confirm that I am the author of this project assignment and that I prepared all of its content myself. In the event that plagiarism is detected, I am aware that I will not meet the requirements for taking the exam.*

# %% [markdown]
# # *Instructions for using this template*<span class="tocSkip"></span>

# %% [markdown]
# You can use the individual seminar template by renaming this file appropriately, filling in your own information, and adding your content under the prepared headings.
#
# If you write the individual project in your own file, make sure that it is properly formatted, contains the required elements including the authorship statement, and that the numerical content is clearly indicated in the section headings of the report.

# %% [markdown]
# ## Table of contents
#
# For the sake of organization and clarity, the individual project report must include a table of contents.
#
# In Visual Studio Code you do not need to create the table of contents separately. **Make sure that the content of your report is properly structured and provided with headings in `markdown` cells**, so that you see an organized table of contents in the "Outline" pane (see the figure).
#
# <img src="kazalo.png" width=600>

# %% [markdown]
# ---

# %% [markdown]
# # Problem definition

# %% [markdown]
# The problem definition should include a brief description of the problem and a figure!

# %% [markdown]
# Figure 3.22 from the source Slavič 2014:
# <img src="slika1.png" width=250>

# %% [markdown]
# The purpose of the individual seminar is to demonstrate the **appropriate selection and use of numerical methods, to comment on how they work, and to evaluate the obtained results**. The choice of physical problem should reflect this, and its solution should cover all the prescribed sections:
#
# * *symbolic computation*,
# * *systems of linear equations*,
# * *interpolation or approximation*,
# * *root finding*,
# * *integration or differentiation*,
# * *solving differential equations*.

# %% [markdown]
# The grade for the individual project consists of:
# * *numerical correctness* (30%),
# * *structure, organization, use of modules, code style (docstrings)* (30%),
# * *personal approach / creative addition* (30%),
# * *prepared code tests and/or user interface* (10%).

# %% [markdown]
# **Submission**: Through the E-classroom (see the study rules!)

# %% [markdown]
# ---

# %% [markdown]
# ## Symbolic computation

# %% [markdown]
# ## ...

# %% [markdown]
# ---

# %% [markdown]
# # Systems of linear equations

# %% [markdown]
# ## ...

# %% [markdown]
# ---

# %% [markdown]
# # Interpolation / approximation

# %% [markdown]
# ## ...

# %% [markdown]
# ---

# %% [markdown]
# # Root finding (solving equations)

# %% [markdown]
# ## ...

# %% [markdown]
# ---

# %% [markdown]
# # Integration / differentiation

# %% [markdown]
# ## ...

# %% [markdown]
# ---

# %% [markdown]
# # Solving differential equations

# %% [markdown]
# ## ...
